# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### **Good luck with taking your exam. Keep working and make your dreams all come true. Seeing the results of all of your hard work will make this struggle worth it. We’re all thinking of you.**
# <b><font color='blue'>AI-PRO Spark Team ITI</font></b>

# %% [markdown]
# # NLP Using PySpark

# %% [markdown]
# ## Objective:
# - The objective from this project is to create a <b>Spam filter using NaiveBayes classifier</b>.
# - It is required to obtain <b>f1_scored > 0.9</b>.
# - We'll use a dataset from UCI Repository. SMS Spam Detection: https://archive.ics.uci.edu/ml/datasets/SMS+Spam+Collection
# - Data is also provided for you in the assignment (you do not have to download it).

# %% [markdown]
# ## To perform this task follow the following guiding steps:

# %% [markdown]
# ### Create a spark session and import the required libraries

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import *
from pyspark.ml.feature import HashingTF, IDF, Tokenizer, StopWordsRemover, CountVectorizer
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, Imputer
from pyspark.ml import Pipeline

# %%
spark = SparkSession.builder.appName("Final exam").getOrCreate()

# %% [markdown]
# ### Read the readme file to learn more about the data

# %% [markdown]
# ### Read the data into a DataFrame

# %%
df = spark.read.csv('/content/SMSSpamCollection.txt', inferSchema=True, sep='\t')

# %% [markdown]
# ### Print the schema

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)

# %% [markdown]
# ### Rename the first column to 'class' and second column to 'text'

# %%
df = df.withColumnRenamed("_c0","class")
df = df.withColumnRenamed("_c1","text")

# %%
df.printSchema()
# Out:
# root
#  |-- class: string (nullable = true)
#  |-- text: string (nullable = true)

# %% [markdown]
# ### Show the first 10 rows from the dataframe
# - Show once with truncate=True and once with truncate=False

# %%
df.show(10)
# Out:
# +-----+--------------------+
# |class|                text|
# +-----+--------------------+
# |  ham|Go until jurong p...|
# |  ham|Ok lar... Joking ...|
# | spam|Free entry in 2 a...|
# |  ham|U dun say so earl...|
# |  ham|Nah I don't think...|
# | spam|FreeMsg Hey there...|
# |  ham|Even my brother i...|
# |  ham|As per your reque...|
# | spam|WINNER!! As a val...|
# | spam|Had your mobile 1...|
# +-----+--------------------+
# only showing top 10 rows

# %%
df.show(10, truncate=False)
# Out:
# +-----+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |class|text                                                                                                                                                            |
# +-----+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |ham  |Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...                                                 |
# |ham  |Ok lar... Joking wif u oni...                                                                                                                                   |
# ...

# %% [markdown]
# ## Clean and Prepare the Data

# %% [markdown]
# ### Create a new feature column contains the length of the text column

# %%
count_str = udf(lambda x : len(x), IntegerType())
df=df.withColumn('length',count_str('text'))

# %% [markdown]
# ### Show the new dataframe

# %%
df.show()
# Out:
# +-----+--------------------+------+
# |class|                text|length|
# +-----+--------------------+------+
# |  ham|Go until jurong p...|   111|
# |  ham|Ok lar... Joking ...|    29|
# | spam|Free entry in 2 a...|   155|
# |  ham|U dun say so earl...|    49|
# |  ham|Nah I don't think...|    61|
# | spam|FreeMsg Hey there...|   147|
# |  ham|Even my brother i...|    77|
# |  ham|As per your reque...|   160|
# | spam|WINNER!! As a val...|   157|
# | spam|Had your mobile 1...|   154|
# |  ham|I'm gonna be home...|   109|
# | spam|SIX chances to wi...|   136|
# | spam|URGENT! You have ...|   155|
# |  ham|I've been searchi...|   196|
# |  ham|I HAVE A DATE ON ...|    35|
# | spam|XXXMobileMovieClu...|   149|
# |  ham|Oh k...i'm watchi...|    26|
# |  ham|Eh u remember how...|    81|
# |  ham|Fine if thats th...|    56|
# | spam|England v Macedon...|   155|
# +-----+--------------------+------+
# only showing top 20 rows

# %% [markdown]
# ### Get the average text length for each class (give alias name to the average length column)

# %%
from pyspark.sql.functions import avg
df.groupBy("class").agg(avg("length").alias("Avg. Lenght")).show()
# Out:
# +-----+-----------------+
# |class|      Avg. Lenght|
# +-----+-----------------+
# |  ham|71.45431945307645|
# | spam|138.6706827309237|
# +-----+-----------------+

# %% [markdown]
# ## Feature Transformations

# %% [markdown]
# ### In this part you transform you raw text in to tf_idf model :
# - For more information about TF-IDF check the following link: <b>(Not needed for the test)</b>
# https://en.wikipedia.org/wiki/Tf%E2%80%93idf

# %% [markdown]
# ### Perform the following steps to obtain TF-IDF:
# 1. Import the required transformers/estimators for the subsequent steps.
# 2. Create a <b>Tokenizer</b> from the text column.
# 3. Create a <b>StopWordsRemover</b> to remove the <b>stop words</b> from the column obtained from the <b>Tokenizer</b>.
# 4. Create a <b>CountVectorizer</b> after removing the <b>stop words</b>.
# 5. Create the <b>TF-IDF</b> from the <b>CountVectorizer</b>.

# %%
#2
tokenizer = Tokenizer(inputCol="text", outputCol="tokens")

# %%
#3
eng_stopwords = StopWordsRemover.loadDefaultStopWords("english")
remover = StopWordsRemover(stopWords=eng_stopwords, inputCol="tokens", outputCol="clean_tokens")

# %%
#4
countVectorizer = CountVectorizer(inputCol="clean_tokens", outputCol="rawFeatures")

# %%
idf = IDF(inputCol="rawFeatures", outputCol="preprocessed_features")

# %% [markdown]
# - Convert the <b>class column</b> to index using <b>StringIndexer</b>
# - Create feature column from the <b>TF-IDF</b> and <b>lenght</b> columns.

# %%
indexer = StringIndexer(inputCols=['class'], 
                        outputCols=['label'],
                        handleInvalid='keep')

# %% [markdown]
# ## The Model
# - Create a <b>NaiveBayes</b> classifier with the default parameters.

# %%
nb = NaiveBayes()

# %% [markdown]
# ## Pipeline
# ### Create a pipeline model contains all the steps starting from the Tokenizer to the NaiveBays classifier.

# %%
vecAssembler = VectorAssembler(inputCols=['preprocessed_features', 'length'], outputCol='features')

# %%
stages = [tokenizer, remover, countVectorizer, idf, indexer, vecAssembler, nb]

# %% [markdown]
# ### Split your data to trian and test data with ratios 0.7 and 0.3 respectively.

# %%
trainDF, testDF = df.randomSplit([0.7,0.3],seed=42)

# %% [markdown]
# ### Fit your Pipeline model to the training data

# %%
pl = Pipeline(stages=stages)
pl_Model = pl.fit(trainDF)

# %% [markdown]
# ### Perform predictions on tests dataframe

# %%
predDF = pl_Model.transform(testDF)

# %%
predDF.show()
# Out:
# +-----+--------------------+------+--------------------+--------------------+--------------------+---------------------+-----+--------------------+--------------------+--------------------+----------+
# |class|                text|length|              tokens|        clean_tokens|         rawFeatures|preprocessed_features|label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+------+--------------------+--------------------+--------------------+---------------------+-----+--------------------+--------------------+--------------------+----------+
# |  ham| &lt;DECIMAL&gt; ...|   132|[, &lt;decimal&gt...|[, &lt;decimal&gt...|(11001,[3,81,128,...| (11001,[3,81,128,...|  0.0|(11002,[3,81,128,...|[-688.90165603252...|[1.0,1.6326453475...|       0.0|
# ...

# %% [markdown]
# ### Print the schema of the prediction dataframe

# %%
predDF.printSchema()
# Out:
# root
#  |-- class: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- length: integer (nullable = true)
#  |-- tokens: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- clean_tokens: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- rawFeatures: vector (nullable = true)
#  |-- preprocessed_features: vector (nullable = true)
#  |-- label: double (nullable = false)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %% [markdown]
# ## Model Evaluation
# - Use <b>MulticlassClassificationEvaluator</b> to calculate the <b>f1_score</b>.

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator = MulticlassClassificationEvaluator(predictionCol = "prediction", labelCol='label', metricName="f1")
evaluator.evaluate(predDF)
# Out:
# 0.9727502290227267

# %% [markdown]
# # GOOD LUCK
# <b><font color='GREEN'>AI-PRO Spark Team ITI</font></b>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
